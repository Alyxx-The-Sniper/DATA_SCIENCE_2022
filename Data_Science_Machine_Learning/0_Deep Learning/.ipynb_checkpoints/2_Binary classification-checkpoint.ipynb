# %% [markdown]
# # work in progress...

# %% [markdown]
# # Classification
#
# Survival prediction of patients with heart failure.

# %% [markdown]
# ![d3.jpg](attachment:d3.jpg)

# %% [markdown]
# `Data Source: ` [Heart Failure](https://www.kaggle.com/datasets/andrewmvd/heart-failure-clinical-data)

# %% [markdown]
# In this project, we will use a [dataset from Kaggle](https://www.kaggle.com/datasets/andrewmvd/heart-failure-clinical-data) to predict the survival of patients with heart failure from serum creatinine and ejection fraction, and other factors such as age, anemia, diabetes, and so on.

# %% [markdown]
# `About The Dataset:`
#
# Cardiovascular diseases (CVDs) are the number 1 cause of death globally, taking an estimated 17.9 million lives each year, which accounts for 31% of all deaths worlwide.
# Heart failure is a common event caused by CVDs and this dataset contains 12 features that can be used to predict mortality by heart failure.
#
# Most cardiovascular diseases can be prevented by addressing behavioural risk factors such as tobacco use, unhealthy diet and obesity, physical inactivity and harmful use of alcohol using population-wide strategies.
#
# People with cardiovascular disease or who are at high cardiovascular risk (due to the presence of one or more risk factors such as hypertension, diabetes, hyperlipidaemia or already established disease) need early detection and management wherein a machine learning model can be of great help.

# %% [markdown]
# `Data Dictionary:`

# %% [markdown]
# 1. Feature details
#
# ![h.png](attachment:h.png)

# %% [markdown]
# 2. Boolean features
#    - Sex - 0 = Female, Male = 1
#    - Diabetes - 0 = No, 1 = Yes
#    - Anaemia - 0 = No, 1 = Yes
#    - High_blood_pressure - 0 = No, 1 = Yes
#    - Smoking - 0 = No, 1 = Yes
#    - DEATH_EVENT - 0 = No, 1 = Yes

# %% [markdown]
# 3. Other informations
#       - mcg/L: micrograms per liter.
#       - mL: microliter.
#       - mEq/L: milliequivalents per litre
#       - The time feature seams to be highly correlated to the death event but there is no concret information of how this               metric was measured patient by patient. Which makes it hard to use it in the analysis.

# %% [markdown]
# ***

# %% [markdown]
# ### Load Libraries and Data Inspection

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
# from collections import Counter
from sklearn.compose import ColumnTransformer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer
from tensorflow.keras import layers
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv('heart_failure.csv')
print(df.shape)
df.head()
# Out:
# (299, 15)
#    Unnamed: 0   age anaemia  creatinine_phosphokinase diabetes  \
# 0           0  75.0      no                       582       no
# 1           1  55.0      no                      7861       no
# 2           2  65.0      no                       146       no
# 3           3  50.0     yes                       111       no
# 4           4  65.0     yes                       160      yes
#
#    ejection_fraction high_blood_pressure  platelets  serum_creatinine  \
# 0                 20                 yes  265000.00               1.9
# 1                 38                  no  263358.03               1.1
# 2                 20                  no  162000.00               1.3
# 3                 20                  no  210000.00               1.9
# 4                 20                  no  327000.00               2.7
#
#    serum_sodium  sex smoking  time  DEATH_EVENT death_event
# 0           130  yes      no     4            1         yes
# 1           136  yes      no     6            1         yes
# 2           129  yes     yes     7            1         yes
# 3           137  yes      no     7            1         yes
# 4           116   no      no     8            1         yes

# %% [markdown]
# In this dataset, we will use column `death_event` as our class label.

# %% [markdown]
# ### Class Distribution (death_event)

# %% [markdown]
# Only 32% of our samples failed to survive given of heart failure.

# %%
print(df['death_event'].value_counts())
# proportion
df['death_event'].value_counts() / len(df)
# Out:
# no     203
# yes     96
# Name: death_event, dtype: int64
# no     0.67893
# yes    0.32107
# Name: death_event, dtype: float64

# %% [markdown]
# `We have a very small and slightly imbalance dataset`. We can't confidently use accuracy as our scoring method.
#
# `note:` For unbalance dataset we must use recall, precision and f1 for scoring.
#
# `recall:` number of correct prediction out of total Actual Positive. usecase if we need to reduce the False Negative like in cancer detection, we dont want our model to predict a person to be negative while the truth is positive.
#
# `precision:` number of positive in Actual out total Positive prediction. i.e in cases we need to reduce the False Positives like in spam detection, we dont want to predict an important mail to be a spam.

# %% [markdown]
# ### General Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                299 non-null    int64
#  1   age                       299 non-null    float64
#  2   anaemia                   299 non-null    object
#  3   creatinine_phosphokinase  299 non-null    int64
#  4   diabetes                  299 non-null    object
#  5   ejection_fraction         299 non-null    int64
#  6   high_blood_pressure       299 non-null    object
#  7   platelets                 299 non-null    float64
#  8   serum_creatinine          299 non-null    float64
#  9   serum_sodium              299 non-null    int64
#  10  sex                       299 non-null    object
#  11  smoking                   299 non-null    object
#  12  time                      299 non-null    int64
#  13  DEATH_EVENT               299 non-null    int64
#  14  death_event               299 non-null    object
# dtypes: float64(3), int64(6), object(6)
# memory usage: 35.2+ KB

# %% [markdown]
# Anaemia, diabets, high_blood_pressure, sex, and smoking are in 'str' datatype. In TensorFlow with Keras, we needs to convert all the categorical features and labels into one-hot encoding vectors.

# %% [markdown]
# ### Define X and y
# Lets define first our class and features. One advantage of Neural Network to traditional Machine Learning algorithm is that we don't need to do a feature selection, Neural Network learn from it's data and adjust features weight accordingly.

# %%
y = df['death_event']
# age to smoking
X = df.loc[:,'age':'smoking']
X.head(3)
# Out:
#     age anaemia  creatinine_phosphokinase diabetes  ejection_fraction  \
# 0  75.0      no                       582       no                 20
# 1  55.0      no                      7861       no                 38
# 2  65.0      no                       146       no                 20
#
#   high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex smoking
# 0                 yes  265000.00               1.9           130  yes      no
# 1                  no  263358.03               1.1           136  yes      no
# 2                  no  162000.00               1.3           129  yes     yes

# %% [markdown]
# ### One-Hot Encoding
# One hot encode our X features. Convert categorical features (anaemia, diabets, high_blood_pressure, sex, and smoking are) to one-hot encoding vectors and assign the result back to variable X.

# %%
X = pd.get_dummies(X)
X.head(3)
# Out:
#     age  creatinine_phosphokinase  ejection_fraction  platelets  \
# 0  75.0                       582                 20  265000.00
# 1  55.0                      7861                 38  263358.03
# 2  65.0                       146                 20  162000.00
#
#    serum_creatinine  serum_sodium  anaemia_no  anaemia_yes  diabetes_no  \
# 0               1.9           130           1            0            1
# 1               1.1           136           1            0            1
# 2               1.3           129           1            0            1
#
#    diabetes_yes  high_blood_pressure_no  high_blood_pressure_yes  sex_no  \
# 0             0                       0                        1       0
# 1             0                       1                        0       0
# 2             0                       1                        0       0
#
#    sex_yes  smoking_no  smoking_yes
# 0        1           1            0
# 1        1           1            0
# 2        1           0            1

# %% [markdown]
# ### Split data
# Splitting our train and test data to 70:30 ratio.

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.3, 
                                                    random_state = 7
                                                   )

print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (209, 16) (90, 16) (209,) (90,)

# %% [markdown]
# ### Standardized
# Standardized our features.

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# ### Label Encoder
# Convert the class/label to integers ranging from 0 to the number of classes.

# %%
lencoder = LabelEncoder()
y_train = lencoder.fit_transform(y_train) 
y_test = lencoder.fit_transform(y_test)

# Show mapping
class_mapping = {l: i for i, l in enumerate(lencoder.classes_)}
class_mapping
# Out:
# {'no': 0, 'yes': 1}

# %% [markdown]
# ### Designing a Deep Learning Model For Classification

# %%
# number of features
n_features = x_train.shape[1]

# model design
model = Sequential()

# input layer
model.add(Dense(n_features, activation='relu'))


# hidden layer 1
model.add(Dense(256, activation='relu', kernel_initializer='he_normal'))
model.add(layers.Dropout(0.15))


# output layer
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ### Compile the Model
# The model is optimized using the `adam` optimizer and seeks to minimize the `cross-entropy` loss. Using `Recall` as our metric. We need to reduce the False Negative rate because we dont want our model to predict a person to be negative while the truth is positive.

# %%
model.compile(loss='binary_crossentropy', metrics=['Recall'], optimizer='adam')

# %% [markdown]
# ### Early Stopping

# %%
# reference https://keras.io/api/callbacks/early_stopping/
stop = EarlyStopping(monitor='val_loss',
                     patience=20,
                     verbose=1)

# %% [markdown]
# ### Training Phase

# %%
# # fix random seed for reproducibility
# tf.random.set_seed(7)


h = model.fit(x_train, y_train, 
               validation_data= (x_test, y_test), 
               epochs=100, 
               batch_size= 64,
               verbose=1,
               callbacks=[stop]
             )

y_pred = model.predict(x_test)
y_pred = (y_pred >= 0.5)
Recall2    = recall_score(y_test, y_pred)
Recall2
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 61ms/step - loss: 0.8137 - recall: 0.8451 - val_loss: 0.6892 - val_recall: 0.6800
# Epoch 2/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7002 - recall: 0.5493 - val_loss: 0.6111 - val_recall: 0.5200
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6680 - recall: 0.3944 - val_loss: 0.5887 - val_recall: 0.3200
# Epoch 4/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6488 - recall: 0.2958 - val_loss: 0.5843 - val_recall: 0.2400
# Epoch 5/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6620 - recall: 0.2113 - val_loss: 0.5812 - val_recall: 0.1200
# Epoch 6/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6506 - recall: 0.1690 - val_loss: 0.5754 - val_recall: 0.2000
# Epoch 7/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6243 - recall: 0.2676 - val_loss: 0.5688 - val_recall: 0.3200
# Epoch 8/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5964 - recall: 0.2817 - val_loss: 0.5657 - val_recall: 0.3600
# Epoch 9/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6129 - recall: 0.3803 - val_loss: 0.5648 - val_recall: 0.4000
# Epoch 10/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5758 - recall: 0.5070 - val_loss: 0.5627 - val_recall: 0.4400
# Epoch 11/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5885 - recall: 0.3944 - val_loss: 0.5574 - val_recall: 0.4000
# Epoch 12/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5963 - recall: 0.4085 - val_loss: 0.5516 - val_recall: 0.4000
# Epoch 13/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5843 - recall: 0.3662 - val_loss: 0.5464 - val_recall: 0.3600
# Epoch 14/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5853 - recall: 0.3662 - val_loss: 0.5416 - val_recall: 0.3600
# Epoch 15/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5777 - recall: 0.3803 - val_loss: 0.5371 - val_recall: 0.3600
# Epoch 16/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5581 - recall: 0.2817 - val_loss: 0.5317 - val_recall: 0.3600
# Epoch 17/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5543 - recall: 0.3944 - val_loss: 0.5271 - val_recall: 0.4000
# Epoch 18/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5498 - recall: 0.3521 - val_loss: 0.5254 - val_recall: 0.4000
# Epoch 19/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5621 - recall: 0.4085 - val_loss: 0.5230 - val_recall: 0.4800
# Epoch 20/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5575 - recall: 0.5211 - val_loss: 0.5209 - val_recall: 0.5200
# Epoch 21/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5527 - recall: 0.5634 - val_loss: 0.5170 - val_recall: 0.5200
# Epoch 22/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5313 - recall: 0.5915 - val_loss: 0.5096 - val_recall: 0.4800
# Epoch 23/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5241 - recall: 0.5634 - val_loss: 0.5033 - val_recall: 0.4800
# Epoch 24/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5489 - recall: 0.4930 - val_loss: 0.4997 - val_recall: 0.4800
# Epoch 25/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5165 - recall: 0.4366 - val_loss: 0.4972 - val_recall: 0.4400
# Epoch 26/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5435 - recall: 0.4507 - val_loss: 0.4976 - val_recall: 0.4800
# Epoch 27/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5200 - recall: 0.4648 - val_loss: 0.4974 - val_recall: 0.4800
# Epoch 28/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5011 - recall: 0.4789 - val_loss: 0.4970 - val_recall: 0.5200
# Epoch 29/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4955 - recall: 0.5070 - val_loss: 0.4977 - val_recall: 0.5200
# Epoch 30/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5098 - recall: 0.4930 - val_loss: 0.4988 - val_recall: 0.5200
# Epoch 31/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5147 - recall: 0.4789 - val_loss: 0.5006 - val_recall: 0.5200
# Epoch 32/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5105 - recall: 0.4648 - val_loss: 0.5024 - val_recall: 0.6400
# Epoch 33/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5029 - recall: 0.4648 - val_loss: 0.5011 - val_recall: 0.6400
# Epoch 34/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5023 - recall: 0.5775 - val_loss: 0.4972 - val_recall: 0.6400
# Epoch 35/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5031 - recall: 0.5775 - val_loss: 0.4934 - val_recall: 0.6400
# Epoch 36/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5056 - recall: 0.4789 - val_loss: 0.4865 - val_recall: 0.5200
# Epoch 37/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4844 - recall: 0.4648 - val_loss: 0.4828 - val_recall: 0.4800
# Epoch 38/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4903 - recall: 0.4366 - val_loss: 0.4815 - val_recall: 0.4800
# Epoch 39/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4919 - recall: 0.5634 - val_loss: 0.4799 - val_recall: 0.5600
# Epoch 40/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4856 - recall: 0.5352 - val_loss: 0.4794 - val_recall: 0.6000
# Epoch 41/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4834 - recall: 0.5775 - val_loss: 0.4792 - val_recall: 0.6800
# Epoch 42/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4820 - recall: 0.5915 - val_loss: 0.4754 - val_recall: 0.6800
# Epoch 43/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4784 - recall: 0.5493 - val_loss: 0.4708 - val_recall: 0.6000
# Epoch 44/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4841 - recall: 0.5775 - val_loss: 0.4680 - val_recall: 0.6000
# Epoch 45/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4523 - recall: 0.5634 - val_loss: 0.4662 - val_recall: 0.6400
# Epoch 46/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4734 - recall: 0.5352 - val_loss: 0.4658 - val_recall: 0.6400
# Epoch 47/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4760 - recall: 0.5775 - val_loss: 0.4656 - val_recall: 0.6400
# Epoch 48/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4818 - recall: 0.5493 - val_loss: 0.4651 - val_recall: 0.6400
# Epoch 49/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4767 - recall: 0.5070 - val_loss: 0.4654 - val_recall: 0.6000
# Epoch 50/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4565 - recall: 0.5493 - val_loss: 0.4652 - val_recall: 0.5600
# Epoch 51/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4576 - recall: 0.5070 - val_loss: 0.4647 - val_recall: 0.5600
# Epoch 52/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4548 - recall: 0.5211 - val_loss: 0.4631 - val_recall: 0.5600
# Epoch 53/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4495 - recall: 0.5070 - val_loss: 0.4611 - val_recall: 0.5600
# Epoch 54/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4412 - recall: 0.5634 - val_loss: 0.4593 - val_recall: 0.5600
# Epoch 55/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4405 - recall: 0.5915 - val_loss: 0.4579 - val_recall: 0.5600
# Epoch 56/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4448 - recall: 0.5211 - val_loss: 0.4566 - val_recall: 0.5600
# Epoch 57/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4608 - recall: 0.5493 - val_loss: 0.4560 - val_recall: 0.5600
# Epoch 58/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4419 - recall: 0.5493 - val_loss: 0.4557 - val_recall: 0.5600
# Epoch 59/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4134 - recall: 0.5775 - val_loss: 0.4570 - val_recall: 0.5600
# Epoch 60/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4004 - recall: 0.5634 - val_loss: 0.4573 - val_recall: 0.5600
# Epoch 61/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4316 - recall: 0.5634 - val_loss: 0.4572 - val_recall: 0.5600
# Epoch 62/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4290 - recall: 0.6056 - val_loss: 0.4577 - val_recall: 0.6000
# Epoch 63/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4444 - recall: 0.6338 - val_loss: 0.4584 - val_recall: 0.6000
# Epoch 64/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4355 - recall: 0.6901 - val_loss: 0.4597 - val_recall: 0.6000
# Epoch 65/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4210 - recall: 0.6620 - val_loss: 0.4588 - val_recall: 0.6000
# Epoch 66/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4145 - recall: 0.6620 - val_loss: 0.4613 - val_recall: 0.6000
# Epoch 67/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4244 - recall: 0.5915 - val_loss: 0.4623 - val_recall: 0.6000
# Epoch 68/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4105 - recall: 0.5915 - val_loss: 0.4618 - val_recall: 0.6000
# Epoch 69/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4014 - recall: 0.5915 - val_loss: 0.4621 - val_recall: 0.5600
# Epoch 70/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4153 - recall: 0.6056 - val_loss: 0.4624 - val_recall: 0.5600
# Epoch 71/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3970 - recall: 0.5634 - val_loss: 0.4623 - val_recall: 0.5600
# Epoch 72/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4062 - recall: 0.5352 - val_loss: 0.4631 - val_recall: 0.6000
# Epoch 73/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3783 - recall: 0.6479 - val_loss: 0.4630 - val_recall: 0.6000
# Epoch 74/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3842 - recall: 0.6761 - val_loss: 0.4617 - val_recall: 0.6000
# Epoch 75/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3975 - recall: 0.6620 - val_loss: 0.4596 - val_recall: 0.6000
# Epoch 76/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3949 - recall: 0.6761 - val_loss: 0.4591 - val_recall: 0.6000
# Epoch 77/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3775 - recall: 0.6620 - val_loss: 0.4586 - val_recall: 0.6000
# Epoch 78/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3826 - recall: 0.6479 - val_loss: 0.4592 - val_recall: 0.6000
# Epoch 78: early stopping
# 3/3 [==============================] - 0s 2ms/step
# 0.6

# %% [markdown]
# `Note:` We will get slightly different results if we re-run the training phase multiple times due to algorithm nature of callbacks and validation data.
#
# Consider running the training phase a few times and compare the average outcome.

# %%
h.history.keys()
# Out:
# dict_keys(['loss', 'recall', 'val_loss', 'val_recall'])

# %%
# Plotting for Accuracy

# fig, axs = plt.subplots(1,2,
#                         figsize=(15, 6),
#                         gridspec_kw={'hspace': 0.5, 'wspace': 0.2}) 
# (ax1, ax2) = axs
# # Binary Entrophy
# ax1.plot(h.history['loss'], label='Train')
# ax1.plot(h.history['val_loss'], label='Validation')
# ax1.set_title('Binary Entrophy for train vs validation set')
# ax1.legend(loc="upper right")
# ax1.set_xlabel("# of epochs")
# ax1.set_ylabel("Binary Entrophy")

# # Recall
# ax2.plot(h.history['Accuracy'], label='Train')
# ax2.plot(h.history['val_Accuracy'], label='Validation')
# ax2.set_title('Recall for train vs validation set')
# ax2.legend(loc="upper right")
# ax2.set_xlabel("# of epochs")
# ax2.set_ylabel("Recall")

# %%
#plotting for Recall

fig, axs = plt.subplots(1,2,
                        figsize=(15, 6),
                        gridspec_kw={'hspace': 0.5, 'wspace': 0.2}) 
(ax1, ax2) = axs
# Binary Entrophy
ax1.plot(h.history['loss'], label='Train')
ax1.plot(h.history['val_loss'], label='Validation')
ax1.set_title('Binary Entrophy for train vs validation set')
ax1.legend(loc="upper right")
ax1.set_xlabel("# of epochs")
ax1.set_ylabel("Binary Entrophy")

# Recall
ax2.plot(h.history['recall'], label='Train')
ax2.plot(h.history['val_recall'], label='Validation')
ax2.set_title('Recall for train vs validation set')
ax2.legend(loc="upper right")
ax2.set_xlabel("# of epochs")
ax2.set_ylabel("Recall")
# Out:
# Text(0, 0.5, 'Recall')

# %%
y_pred = model.predict(x_test)
y_pred = (y_pred >= 0.5)
# Out:
# 3/3 [==============================] - 0s 1ms/step

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87        65
#            1       0.68      0.60      0.64        25
#
#     accuracy                           0.81        90
#    macro avg       0.77      0.75      0.76        90
# weighted avg       0.81      0.81      0.81        90

# %%
model_matrix = confusion_matrix(y_test, y_pred)
model_matrix
# Out:
# array([[58,  7],
#        [10, 15]], dtype=int64)

# %%
# Visualize
fig, ax = plt.subplots(figsize=(8,5))

# setting variables
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ['{0:0.0f}'.format(value) for value in model_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in model_matrix.flatten()/np.sum(model_matrix)]
labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)

sns.heatmap(model_matrix, annot=labels, fmt='', cmap='Purples')
# Out:
# <AxesSubplot:>

# %%
Recall2    = recall_score(y_test, y_pred)
Recall2
# Out:
# 0.6

# %% [markdown]
# After playing with different hyperparameters combination value, we were able to produce a model thats not overfit nor underfit and at the same time we minimize the recall score.
#
# Let's try using GridSearchCV if we can reproduce the same hyperpameter and recall score.

# %% [markdown]
# # Hyperpameter Tune in
# We will use GridSearchCV to find the optimal hyperparameter value, however using this method is very CPU computational expensive (there's a technique that can improve training/gridsearch speed but we will not do it here). We will do  search each hyperameter individually with minimum search value.
