# %% [markdown]
# #### Work In Progress...

# %% [markdown]
# # Neural Network (Regression)
# Predicting Medical Insurance Costs

# %% [markdown]
# ![HI.jpg](attachment:HI.jpg)

# %% [markdown]
# Data Source: [Medical Insurance](https://www.kaggle.com/datasets/mirichoi0218/insurance)

# %% [markdown]
# `Project Goal:`
#
# We would like to predict the individual medical costs (charges) given the rest of the columns/features. Since charges represent continuous values (in dollars), we’re performing a regression task.

# %% [markdown]
# `Content:`
# 1.
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ***

# %% [markdown]
# # Import Libraries
# Import python libraries and loading the dataset

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

# from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

from scikeras.wrappers import KerasClassifier, KerasRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, make_scorer, r2_score

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('insurance.csv') #load the dataset
print(df.shape)
df.head(3)
# Out:
# (1338, 7)
#    age  sex    bmi  children  smoker     region     charges
# 0   19    1  27.90         0       1  southwest  16884.9240
# 1   18    0  33.77         1       0  southeast   1725.5523
# 2   28    0  33.00         3       0  southeast   4449.4620

# %% [markdown]
# ### Data Cleaning

# %%
# inspect categorical features
df.region.unique()
# Out:
# array(['southwest', 'southeast', '0rthwest', '0rtheast'], dtype=object)

# %%
# clean categorical features
df.region = df.region.replace('0', 'no', regex=True)
df.region.unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %% [markdown]
# ### Define X and y

# %%
X = df.iloc[:,0:6]
y = df.iloc[:,-1]

# %% [markdown]
# ### One-Hot Encoding For Categorical Variables

# %%
X = pd.get_dummies(X) 
X.head(2)
# Out:
#    age  sex    bmi  children  smoker  region_northeast  region_northwest  \
# 0   19    1  27.90         0       1                 0                 0
# 1   18    0  33.77         1       0                 0                 0
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0

# %% [markdown]
# ### Split data

# %% [markdown]
# `Note:`
#
# Train,Test, Validation splits comes differently in terms of Neural Networks. Usually using traditional ML algorithm we do the process is to split a given data set into 70% train data set and 30% test data set (ideally). In the training phase, we fit the model on the training data. And now to evaluate the model (i.e., to check how well the model is able to predict on unseen data), we run the model against the test data and get the predicted results. Since we already know what the expected results are, we compare the predicted and the real results to get the accuracy of the model.
# If the accuracy is not up to the desired level, we repeat the above process (train, test, compare) until the desired accuracy is achieved.
#
# In Neural Networks approach, we do spliting our data set in train_test_plit. And In training/fitting phase we do spliting again. We split out training and validation_set. Then finally we will test our model using the testing set(unseen data) and compare the predicted result to the real result.

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.1, # 10%
                                                    random_state = 42)

print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (1204, 9) (134, 9) (1204,) (134,)

# %% [markdown]
# ### Standardize

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# # Designing Model

# %%
# Creating a keras sequential object
model_regr = Sequential()

# %%
# fix random seed for reproducibility
seed = 7
tf.random.set_seed(seed)

# %% [markdown]
# ### DEFINE MODEL

# %%
############## INPUT LAYER ##########################################
model_regr.add(Dense(units = X.shape[1] , activation = 'relu')) 


############## HIDDEN LAYER 1 ##########################################
# `Note:`
# How do we choose the number of hidden layers and the number of units per layer? That is a tough question and there 
# is no good answer. The rule of thumb is to start with one hidden layer and add as many units as we have features in the
# dataset. However, this might not always work. We need to try things out and observe our learning curve.

# there are a numbers of activation functions such as softmax, sigmoid, 
# but ReLU (relu) (Rectified Linear Unit) is very effective in many applications and we’ll use it here.
model_regr.add(Dense(128, activation = 'relu'))
# Adding dropout
model_regr.add(layers.Dropout(0.1))

############## OUTPUT LAYER ##########################################
model_regr.add(Dense(1, activation = 'linear'))

# %% [markdown]
# ### OPTIMIZER

# %%
# We have a lot of optimizers such as SGD (Stochastic Gradient Descent optimizer), Adam, RMSprop, and others.
# right now adam is the best one as its solved previous optmizers issues.
opt = Adam(learning_rate = 0.01) # by default adam learning rate is 0.0.1

# %% [markdown]
# ### COMPILE MODEL

# %%
# loss/cost 
# MSE, MAE, Huber loss  
model_regr.compile(loss='mse',  metrics=['mae'], optimizer=opt)

# %% [markdown]
# ### TRAINING PHASE/FIT THE MODEL

# %% [markdown]
# Add early stoping when theres no improvement.

# %%
# reference https://keras.io/api/callbacks/early_stopping/
stop = EarlyStopping(monitor='val_loss', # validation_split 20%
                     mode='min', 
                     patience=30,
                     verbose=1)

# %% [markdown]
# Here we define a validation_set to 20%. Spliting our training set in 80:20 ratio

# %%
h = model_regr.fit(x_train, y_train, 
               validation_split=0.2, # fraction of the training data to be used in validation
               epochs=100, 
               batch_size=1,
               verbose=1,
               callbacks=[stop])
# Out:
# Epoch 1/100
# 963/963 [==============================] - 1s 1ms/step - loss: 83437448.0000 - mae: 6288.5537 - val_loss: 33264370.0000 - val_mae: 3740.7200
# Epoch 2/100
# 963/963 [==============================] - 1s 906us/step - loss: 36894064.0000 - mae: 4208.9814 - val_loss: 34369888.0000 - val_mae: 3742.1675
# Epoch 3/100
# 963/963 [==============================] - 1s 927us/step - loss: 34922344.0000 - mae: 4057.7229 - val_loss: 33843292.0000 - val_mae: 3629.2991
# Epoch 4/100
# 963/963 [==============================] - 1s 952us/step - loss: 34341912.0000 - mae: 3994.8416 - val_loss: 35273316.0000 - val_mae: 3605.9211
# Epoch 5/100
# 963/963 [==============================] - 1s 957us/step - loss: 33215408.0000 - mae: 3905.5620 - val_loss: 31167906.0000 - val_mae: 3413.9343
# Epoch 6/100
# 963/963 [==============================] - 1s 911us/step - loss: 31383812.0000 - mae: 3677.8379 - val_loss: 35461840.0000 - val_mae: 3424.2217
# Epoch 7/100
# 963/963 [==============================] - 1s 908us/step - loss: 30655076.0000 - mae: 3612.4954 - val_loss: 32890820.0000 - val_mae: 3357.9912
# Epoch 8/100
# 963/963 [==============================] - 1s 917us/step - loss: 29265142.0000 - mae: 3484.8801 - val_loss: 28737776.0000 - val_mae: 3030.2371
# Epoch 9/100
# 963/963 [==============================] - 1s 910us/step - loss: 27898856.0000 - mae: 3340.9819 - val_loss: 27661942.0000 - val_mae: 3169.4707
# Epoch 10/100
# 963/963 [==============================] - 1s 935us/step - loss: 27003354.0000 - mae: 3208.0271 - val_loss: 26311324.0000 - val_mae: 3130.0859
# Epoch 11/100
# 963/963 [==============================] - 1s 964us/step - loss: 26114158.0000 - mae: 3144.9302 - val_loss: 26791402.0000 - val_mae: 3327.1829
# Epoch 88/100
# 963/963 [==============================] - 1s 883us/step - loss: 22104366.0000 - mae: 2798.0098 - val_loss: 23890392.0000 - val_mae: 2579.8315
# Epoch 89/100
# 963/963 [==============================] - 1s 883us/step - loss: 22394948.0000 - mae: 2833.4404 - val_loss: 25898096.0000 - val_mae: 2716.8213
# Epoch 90/100
# 963/963 [==============================] - 1s 901us/step - loss: 22119110.0000 - mae: 2791.4568 - val_loss: 24550216.0000 - val_mae: 2899.7549
# Epoch 91/100
# 963/963 [==============================] - 1s 906us/step - loss: 21325252.0000 - mae: 2776.6196 - val_loss: 26242812.0000 - val_mae: 3374.3916
# Epoch 92/100
# 963/963 [==============================] - 1s 911us/step - loss: 22044804.0000 - mae: 2859.8848 - val_loss: 26918192.0000 - val_mae: 2741.2263
# Epoch 93/100
# 963/963 [==============================] - 1s 917us/step - loss: 21969024.0000 - mae: 2812.5117 - val_loss: 25222156.0000 - val_mae: 2796.1865
# Epoch 94/100
# 963/963 [==============================] - 1s 902us/step - loss: 21481860.0000 - mae: 2784.0837 - val_loss: 23991906.0000 - val_mae: 2747.3835
# Epoch 95/100
# 963/963 [==============================] - 1s 892us/step - loss: 22123698.0000 - mae: 2815.4700 - val_loss: 23736216.0000 - val_mae: 3162.4487
# Epoch 96/100
# 963/963 [==============================] - 1s 888us/step - loss: 21399144.0000 - mae: 2836.5457 - val_loss: 24546318.0000 - val_mae: 2569.3879
# Epoch 97/100
# 963/963 [==============================] - 1s 915us/step - loss: 21573544.0000 - mae: 2786.3438 - val_loss: 32186944.0000 - val_mae: 2833.5720
# Epoch 98/100
# 963/963 [==============================] - 1s 891us/step - loss: 21804328.0000 - mae: 2794.9810 - val_loss: 25034686.0000 - val_mae: 2900.4875
# Epoch 99/100
# 963/963 [==============================] - 1s 886us/step - loss: 21784198.0000 - mae: 2807.2639 - val_loss: 25209206.0000 - val_mae: 2840.3088
# Epoch 100/100
# 963/963 [==============================] - 1s 889us/step - loss: 21644790.0000 - mae: 2838.8564 - val_loss: 23560498.0000 - val_mae: 2709.4128

# %% [markdown]
# ### Model Summary

# %%
# view summary
model_regr.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (1, 9)                    90
#
#  dense_1 (Dense)             (1, 128)                  1280
#
#  dropout (Dropout)           (1, 128)                  0
#
#  dense_2 (Dense)             (1, 1)                    129
#
# =================================================================
# Total params: 1,499
# Trainable params: 1,499
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Visualization

# %%
h.history.keys()
# Out:
# dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])

# %%
#plotting

fig, axs = plt.subplots(1,2,
                        figsize=(15, 6),
                        gridspec_kw={'hspace': 0.5, 'wspace': 0.2}) 
(ax1, ax2) = axs
# MSE
ax1.plot(h.history['loss'], label='Train') 
ax1.plot(h.history['val_loss'], label='Validation')
ax1.set_title('learning rate=' + str(0.01))
ax1.legend(loc="upper right")
ax1.set_xlabel("# of epochs")
ax1.set_ylabel("loss (MSE)")

#MAE
ax2.plot(h.history['mae'], label='Train')
ax2.plot(h.history['val_mae'], label='Validation')
ax2.set_title('learning rate=' + str(0.01))
ax2.legend(loc="upper right")
ax2.set_xlabel("# of epochs")
ax2.set_ylabel("MAE")
# Out:
# Text(0, 0.5, 'MAE')

# %% [markdown]
# ### Evaluation

# %%
val_mse, val_mae = model_regr.evaluate(x_test, y_test, verbose = 1)
# Out:
# 5/5 [==============================] - 0s 1ms/step - loss: 17992928.0000 - mae: 2403.5139

# %%
y_predict = model_regr.predict(x_test)
# Out:
# 5/5 [==============================] - 0s 750us/step

# %%
r2_score(y_test, y_predict)
# Out:
# 0.8695742194664512

# %% [markdown]
# ### Predicted vs. Actual Charges

# %%
# show/hide code
a = y_test.values.reshape(-1,1).flatten()
b = y_predict.flatten()
diff = (b - a)

sim_data={"Actual Charges":a, 'Predicted Charges':b, 'Difference':np.round(diff,2)}

sim_data=pd.DataFrame(sim_data)

# Showing first 5 rows
sim_data.head(5)
# Out:
#    Actual Charges  Predicted Charges  Difference
# 0      9095.06825       10951.575195     1856.51
# 1      5272.17580        5413.418457      141.24
# 2     29330.98315       30374.904297     1043.92
# 3      9301.89355        9243.665039      -58.23
# 4     33750.29180       32848.261719     -902.03

# %% [markdown]
# ### Visualization

# %%
# visualization of actual vs. predicted charges
plt.figure(figsize=(8, 6)) 

plt.scatter(y_test, y_predict, alpha=0.4, color = 'red')
plt.title("Actual Vs. Predicted Charges")
plt.xlabel("Actual Charges")
plt.ylabel("Predicted Charges")
# Out:
# Text(0, 0.5, 'Predicted Charges')

# %% [markdown]
# # GridSearchCV
# Finding the optimal hypeparameters value.

# %% [markdown]
# ### Function For Designing Model
# Function that creates and returns your Keras sequential model (To use in skires wrappers)

# %%
def design_model(features):
  # ann model instance  
  model_regr = Sequential()
  
  
  #### INPUT LAYER>>>>
  #adding the input layer
  model_regr.add(Dense(units = X.shape[1] , activation = 'relu')) 


  #### HIDDEN LAYER1>>>>
  # there are a numbers of activation functions such as softmax, sigmoid, 
  # but ReLU (relu) (Rectified Linear Unit) is very effective in many applications and we’ll use it here.
  model_regr.add(Dense(128, activation = 'relu'))


  #### OUTPUT LAYER>>>>
  model_regr.add(Dense(1, activation = 'linear'))  


  #### Optimizer
  # WE have a lot of optimizers such as SGD (Stochastic Gradient Descent optimizer), Adam, RMSprop, and others.
  # right now adam is the best one as its solved previous optmizers issues.
  opt = Adam(learning_rate = 0.01)
  # loss/cost 
  # MSE, MAE, Huber loss  
  model_regr.compile(loss='mse',  metrics=['mae'], optimizer=opt)  
    

  return model_regr

# %% [markdown]
# ### Invoke Our Fucntion And Pass The x_train Argument Then Save It In a Variable.

# %%
model_regr2 = design_model(x_train)

# %% [markdown]
# ### Training Phase/Fit The Model

# %%
model_regr2.fit(x_train, y_train, 
                validation_split=0.2, 
                verbose=1)
# Out:
# 31/31 [==============================] - 0s 5ms/step - loss: 324299840.0000 - mae: 13392.2930 - val_loss: 321864480.0000 - val_mae: 12848.9375

# %% [markdown]
# To use KerasRegressor, we must define a function that creates and returns your Keras sequential model,(Above Function)
# then pass this function to the model argument when constructing the KerasClassifier class.

# %%
model = KerasRegressor(model = model_regr2)

# %% [markdown]
# ### Setting Up Hyperparameters

# %% [markdown]
# This is computational extensive, we will use small value here.
#
# List of hyperparameters:
#  1. the learning rate
#  2. number of batches
#  3. number of epochs
#  4. number of units per hidden layer
#  5. activation functions.

# %%
param_grid = dict(epochs = [50,100],
                  batch_size = [1,10,50])

# %%
grid = GridSearchCV(estimator=model, 
                    param_grid=param_grid,
                    n_jobs=-1, # use all processor cores of our machine (faster!!)
                    scoring = 'r2',
                    return_train_score = True,
                    cv=3)

grid_result = grid.fit(x_train, y_train)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmp2im7lwx2\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpadgmn6jl\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmprs1ois4c\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmp6bjqyjha\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpr7tv1xgd\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpun9936cj\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpz697n0pd\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpxs_vwax4\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpoknpr1wi\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmp8uf0wqyl\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmp1a2tx27f\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpdocv_i5q\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpjptqhx_m\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpxz04id75\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpvdtn72cu\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpl21hfu1c\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpge_61f70\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmphdkcpq1n\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpfu8c__nh\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpber_lzdz\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpv8flj6rk\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpfxy38qkp\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmp6hha1wdd\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpnyzqvcyz\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpaz24o_rf\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpubdlcdea\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmp9nt3xkdf\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpdg7h1pgu\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmp_hbc1c3q\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpc8ztilba\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpmy2yp95r\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmphfj9g0oh\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpbejakznz\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmptgnfx3c2\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpvcj4bfu4\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpuu2nvjo7\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmp7454qh_r\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpe4_m1cbd\assets
# INFO:tensorflow:Assets written to: C:\Users\Toto\AppData\Local\Temp\tmpnx89250f\assets
# Epoch 1/100
# 121/121 [==============================] - 0s 909us/step - loss: 265257264.0000 - mae: 11403.9365
# Epoch 2/100
# 121/121 [==============================] - 0s 925us/step - loss: 64789128.0000 - mae: 5562.0713
# Epoch 3/100
# 121/121 [==============================] - 0s 892us/step - loss: 36403184.0000 - mae: 4362.3853
# Epoch 4/100
# 121/121 [==============================] - 0s 867us/step - loss: 34877648.0000 - mae: 4065.6274
# Epoch 5/100
# 121/121 [==============================] - 0s 950us/step - loss: 34117656.0000 - mae: 3976.9177
# Epoch 6/100
# 121/121 [==============================] - 0s 975us/step - loss: 34318508.0000 - mae: 3955.7549
# Epoch 7/100
# 121/121 [==============================] - 0s 959us/step - loss: 33344566.0000 - mae: 3890.9260
# Epoch 8/100
# 121/121 [==============================] - 0s 917us/step - loss: 33162124.0000 - mae: 3877.6492
# Epoch 9/100
# 121/121 [==============================] - 0s 884us/step - loss: 32981622.0000 - mae: 3902.5203
# Epoch 10/100
# 121/121 [==============================] - 0s 900us/step - loss: 32531368.0000 - mae: 3824.1067
# Epoch 11/100
# 121/121 [==============================] - 0s 984us/step - loss: 32295816.0000 - mae: 3815.7327
# Epoch 12/100
# 121/121 [==============================] - 0s 984us/step - loss: 32047042.0000 - mae: 3739.0220
# Epoch 13/100
# 121/121 [==============================] - 0s 950us/step - loss: 31495916.0000 - mae: 3726.9631
# Epoch 14/100
# 121/121 [==============================] - 0s 900us/step - loss: 30911124.0000 - mae: 3653.3538
# Epoch 15/100
# 121/121 [==============================] - 0s 1ms/step - loss: 30162016.0000 - mae: 3601.8076
# Epoch 16/100
