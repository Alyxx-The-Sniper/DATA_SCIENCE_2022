# %% [markdown]
# # Binnings

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np


df = pd.read_csv('nyc_tree_census.csv')
df  = df.dropna()
print(df.shape)
df.head(3)
# Out:
# (47695, 6)
#    tree_id  trunk_diam status health   spc_common       neighborhood
# 0   199250           8  Alive   Good   crab apple     Lincoln Square
# 1   136891          17  Alive   Good  honeylocust  East Harlem North
# 2   200218           3  Alive   Good       ginkgo          Chinatown

# %% [markdown]
# #### Get min and max value for trunk_diam
# `Note`:  trunk_diam is measured in inches

# %%
print(np.min(df.trunk_diam))
np.max(df.trunk_diam)
# Out:
# 0
# 389

# %% [markdown]
# #### Visualize

# %%
sns.histplot(df.trunk_diam, bins=20)
plt.ylim(0,10)
plt.xlim(0,100)
# Out:
# (0.0, 100.0)

# %% [markdown]
# Our value to bin is from 0 - 389. lets divide this into 4 bins, each bin has a 100 datapoint.
#
# 1. small = 0-25
# 2. medium = 26-50
# 3. large = 51-100
# 4. super_large = 100-400

# %% [markdown]
# #### Store the boundaries

# %% [markdown]
# `Note:`
#
#  * small(< 5inches)
#  * medium(6-10inches)
#  * large(11-25inches)
#  * super_large(> 26inches)

# %%
bins = [0, 5, 10, 25, 400]
bins_name = ['small(< 5inches)', 'medium(6-10inches)', 'large(11-25inches)', 'super_large(> 26inches)']

# %% [markdown]
# #### Create new binned_trunk_diam column that bins the values of the ‘trunk_diam’ column

# %%
df['binned_trunk_diam'] = pd.cut(df['trunk_diam'], bins, labels = bins_name)

# %% [markdown]
# #### Uncomment code to verify

# %%
# example datapoints 5
dfx = df[df['trunk_diam']== 5]
dfx.binned_trunk_diam.unique()
# Out:
# ['small(< 5inches)']
# Categories (4, object): ['small(< 5inches)' < 'medium(6-10inches)' < 'large(11-25inches)' < 'super_large(> 26inches)']

# %% [markdown]
# #### There's seems a null values in our binned_trunk_diam

# %%
df.isna().sum()
# Out:
# tree_id               0
# trunk_diam            0
# status                0
# health                0
# spc_common            0
# neighborhood          0
# binned_trunk_diam    18
# dtype: int64

# %% [markdown]
# #### Show null values
# Null values are datapoints that has zero trunk diameter. We can delete these records.

# %%
df1 = df[df.isna().any(axis=1)]
df1.head(3)
# Out:
#        tree_id  trunk_diam status health        spc_common  \
# 854     424438           0  Alive   Good  eastern redcedar
# 4354    541153           0  Alive   Good      Norway maple
# 14040   637186           0  Alive   Good           Sophora
#
#                                             neighborhood binned_trunk_diam
# 854                                         Baisley Park               NaN
# 4354   Todt Hill-Emerson Hill-Heartland Village-Light...               NaN
# 14040                                   South Ozone Park               NaN

# %%
# drop nulls
df = df.dropna()

# %% [markdown]
# #### Frequency of each bins

# %%
df['binned_trunk_diam'].value_counts()
# Out:
# large(11-25inches)         18446
# small(< 5inches)           14157
# medium(6-10inches)         11236
# super_large(> 26inches)     3838
# Name: binned_trunk_diam, dtype: int64

# %% [markdown]
# #### Visualize

# %%
plt.figure(figsize = (8,4))
ax = sns.countplot(x = 'binned_trunk_diam', data = df)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
plt.title('Trunk Sizes Category Count')

for i in ax.containers:
    ax.bar_label(i,)

plt.show()

# %% [markdown]
# #### Proportion

# %%
import plotly.express as px
fig = px.pie(df, 'binned_trunk_diam')

fig.update_layout(title="Proportion of binned_trunk_diam")
fig.update_traces(textposition='inside',
                  textinfo='percent+label', showlegend=False)
fig.show()
# Out:
# <div>                            <div id="769ca7b9-d1c9-4674-acee-c29ce504601c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("769ca7b9-d1c9-4674-acee-c29ce504601c")) {                    Plotly.newPlot(                        "769ca7b9-d1c9-4674-acee-c29ce504601c",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"binned_trunk_diam=%{label}<extra></extra>","labels":["medium(6-10inches)","large(11-25inches)","small(< 5inches)","large(11-25inches)","large(11-25inches)","large(11-25inches)","small(< 5inches)","small(< 5inches)","large(11-25inches)","large(11-25inches)","large(11-25inches)","small(< 5inches)","small(< 5inches)","small(< 5inches)","medium(6-10inches)","small(< 5inches)","large(11-25inches)","medium(6-10inches)","large(11-25inches)","large(11-25inches)","small(< 5inches)","medium(6-10inches)","super_large(> 26inches)","large(11-25inches)","medium(6-10inches)","large(11-25inches)","small(< 5inches)","large(11-25inches)","medium(6-10inches)","large(11-25inches)","large(11-25inches)","small(< 5inches)","small(< 5inches)","large(11-25inches)","super_large(> 26inches)","small(< 5inches)","large(11-25inches)","medium(6-10inches)","medium(6-10inches)","super_large(> 26inches)","large(11-25inches)","large(11-25inches)","medium(6-10inches)","small(< 5inches)","super_large(> 26inches)","large(11-25inches)","small(< 5inches)","small(< 5inches)","large(11-25inches)","super_large(> 26inches)","small(< 5inches)","small(< 5inches)","small(< 5inches)","large(11-25inches)","large(11-25inches)","small(< 5inches)","medium(6-10inches)","super_large(> 26inches)","large(11-25inches)","medium(6-10inches)","large(11-25inches)","medium(6-10inches)","medium(6-10inches)","small(< 5inches)","small(< 5inches)","medium(6-10inches)","large(11-25inches)","large(11-25inches)","small(< 5inches)","medium(6-10inches)","large(11-25inches)","large(11-25inches)","medium(6-10inches)","small(< 5inches)","small(< 5inches)","large(11-25inches)","medium(6-10inches)","large(11-25inches)","large(11-25inches)","small(< 5inches)","medium(6-10inches)","medium(6-10inches)","medium(6-10inches)","small(< 5inches)","medium(6-10inches)","small(< 5inches)","small(< 5inches)","medium(6-10inches)","small(< 5inches)","large(11-25inches)","large(11-25inches)","medium(6-10inches)","medium(6-10inches)","large(11-25inches)","medium(6-10inches)","medium(6-10inches)","small(< 5inches)","small(< 5inches)","medium(6-10inches)","large(11-25inches)","medium(6-10inches)","small(< 5inches)","small(< 5inches)","small(< 5inches)","large(11-25inches)","small(< 5inches)","large(11-25inches)","large(11-25inches)","large(11-25inches)","large(11-25inches)","small(< 5inches)","medium(6-10inches)","medium(6-10inches)","small(< 5inches)","large(11-25inches)","medium(6-10inches)","large(11-25inches)","large(11-25inches)","large(11-25inches)","super_large(> 26inches)","small(< 5inches)","small(< 5inches)","medium(6-10inches)","medium(6-10inches)","large(11-25inches)","large(11-25inches)","small(< 5inches)","medium(6-10inches)","medium(6-10inches)","small(< 5inches)","medium(6-10inches)","medium(6-10inches)","super_large(> 26inches)","medium(6-10inches)","small(< 5inches)","large(11-25inches)","small(< 5inches)","large(11-25inches)","medium(6-10inches)","large(11-25inches)","large(11-25inches)","small(< 5inches)","medium(6-10inches)","super_large(> 26inches)","large(11-25inches)","large(11-25inches)","large(11-25inches)","large(11-25inches)","large(11-25inches)","large(11-25inches)","large(11-25inches)","medium(6-10inches)","medium(6-10inches)","small(< 5inches)","small(< 5inches)","small(< 5inches)","large(11-25inches)","large(11-25inches)","large(11-25inches)","large(11-25inches)","large(11-25inches)","large(11-25inches)","large ...
