# %% [markdown]
# https://datavizcatalogue.com/methods/box_plot.html

# %% [markdown]
# #  Line Graphs

# %% [markdown]
# ### `Line Graphs that visualize page visits and limes sold per Months`

# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# `Data:`

# %%
# Months and visits per Month
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
visits_per_month = [9695, 7909, 10831, 12942, 12495, 16794, 14161, 12762, 12777, 12439, 10309, 8724]

# numbers of limes of different species sold each month
key_limes_per_month = [92.0, 109.0, 124.0, 70.0, 101.0, 79.0, 106.0, 101.0, 103.0, 90.0, 102.0, 106.0]
persian_limes_per_month = [67.0, 51.0, 57.0, 54.0, 83.0, 90.0, 52.0, 63.0, 51.0, 44.0, 64.0, 78.0]
blood_limes_per_month = [75.0, 75.0, 76.0, 71.0, 74.0, 77.0, 69.0, 80.0, 63.0, 69.0, 73.0, 82.0]

# %%
plt.figure(figsize=(12, 8)) 

# Website visits per Month
ax1 = plt.subplot(1,2,1)
plt.xlabel('Months')
plt.ylabel('Numbe of visists')

plt.title('Page visits per Month')
x_values = range(len(months))
ax1.set_xticks(x_values)
ax1.set_xticklabels(months, rotation=30)
plt.plot(x_values, visits_per_month, marker= 'o')


# Limes sold per Month
ax2 = plt.subplot(1,2,2)
plt.plot(x_values, key_limes_per_month,  color= 'green', marker = 'o')
plt.plot(x_values, persian_limes_per_month, color= 'orange', marker = 'o')
plt.plot(x_values, blood_limes_per_month, color= 'red', marker = 'o')

plt.legend(['Key limes','Persian','Blood limes'])

plt.xlabel('Months')
plt.ylabel('Limes Sold')
ax2.set_xticks(x_values)
ax2.set_xticklabels(months, rotation=30)
plt.title('Limes sales per Month')
plt.axis([10,12,70,80])
# Out:
# (10.0, 12.0, 70.0, 80.0)

# %% [markdown]
# # Bar Graphs

# %%
drinks = ["cappuccino", "latte", "chai", "americano", "mocha", "espresso"]
sales1 =  [91, 76, 56, 66, 52, 27]
sales2 = [65, 82, 36, 68, 38, 40]

#create your ax object here
ax = plt.subplot(1,1,1)
ax.set_xticks(range(len(drinks)))
ax.set_xticklabels(drinks)

plt.bar(range(len(drinks)), sales1)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ### `Side-By-Side Bars`

# %% [markdown]
# `Comparing sales for store1 and store2` code1

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
drinks = ["cappuccino", "latte", "chai", "americano", "mocha", "espresso"]
sales1 =  [91, 76, 56, 66, 52, 27 ]
sales2 =  [65, 82, 36, 68, 38, 40 ]



plt.figure(figsize=(12, 8)) 
plt.title('Store 1 vs. Store 2')
plt.xlabel('Store Sales')
plt.ylabel('Sales Amount')


#sales1 data for store1
n = 1  # This is our first dataset (1 of 2)
t = 2 # Number of datasets
d = 6 # Number of sets of bars
w = 0.8 # Width of each bar
x_values = [t*element + w*n for element in range(d)]
store1_x = x_values 

plt.legend(['Store1 Sale'])
plt.bar(store1_x, sales1, label='Store1 Sales')


#sales2 data for store2
n2 = 2 # This is our second dataset (2 of 2)
t2 = 2 # Number of datasets
d2 = 6 # Number of sets of bars
w2 = 0.8 # Width of each bar
x_values2 = [t*element + w2*n2 for element in range(d2)]
store2_x = x_values2 


# plt.legend(['Store2 Sale'])
plt.bar(store2_x, sales2, label='Store2 Sales')


# show both graphs
plt.legend()
# plt.show()

# %% [markdown]
# `Comparing sales for store1 and store2` code2

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
drinks = ["cappuccino", "latte", "chai", "americano", "mocha", "espresso"]
sales1 =  [91, 76, 56, 66, 52, 27 ]
sales2 =  [65, 82, 36, 68, 38, 40 ]


x = np.arange(len(months))  # the months locations
width = 0.35  # the width of the bars



fig, ax = plt.subplots(figsize=(12, 8))
rects1 = ax.bar(x - width/2, sales1, width, label='Store 1 Sales')
rects2 = ax.bar(x + width/2, sales2, width, label='Store 2 Sales')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Sales Amount')
ax.set_title('Store 1 vs. Store 2')
ax.set_xticks(x)
ax.set_xticklabels(months)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)


fig.tight_layout()

# %% [markdown]
# ### `Stacked Bars`

# %% [markdown]
# `Plotting the hours I spent on entertaining myself with video games and books in the past week, wanted to also get a feel for total hours spent, then I could create a stacked bar`

# %%
video_game_hours = [1, 2, 2, 1, 2]
book_hours = [2, 3, 4, 2, 1]

# %%
plt.bar(range(len(video_game_hours)), video_game_hours)
plt.bar(range(len(book_hours)), book_hours, bottom=video_game_hours)
plt.legend(['Video Games','Reading Books'])

# %% [markdown]
# ### `Error Bars`

# %% [markdown]
# `Usage:`
#
# - The average number of students in a 3rd grade classroom is 30, but some classes have as few as 18 and others have as many as 35 students.
#
# - We measured that the weight of a certain fruit was 35g, but we know that our scale isn’t very precise, so the true weight of the fruit might be as much as 40g or as little as 30g.
#
# - The average price of a soda is 1.00 dollar, but we also want to communicate that the standard deviation is 0.20 dollar.

# %%
drinks = ["cappuccino", "latte", "chai", "americano", "mocha", "espresso"]
ounces_of_milk = [6, 9, 4, 0, 9, 0]

# %%
ax = plt.subplot(1,1,1)
plt.ylabel('Ounces of milk')
plt.title('Amount of Milk in each drinks')

ax.set_xticks(range(len(drinks)))
ax.set_xticklabels(drinks, rotation = 30)

plt.bar(range(len(drinks)), ounces_of_milk)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ### ` Including a list error, with an error of 10% on each amount of milk`

# %%
error = []
for i in ounces_of_milk:
    error.append(i * 0.1)
error
# Out:
# [0.6000000000000001, 0.9, 0.4, 0.0, 0.9, 0.0]

# %%
plt.figure(figsize=(12, 8)) 
plt.bar(range(len(drinks)), ounces_of_milk, yerr=error, capsize=20)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ### `Fill Between`

# %% [markdown]
# Displaying errors of margin on line graph

# %% [markdown]
# `This data is a projection of future revenue. We don’t know that this will be the revenue, but it’s an estimate based on the patterns of past years. We can say that the real revenue will probably be plus or minus 10% of each value.`

# %%
months = range(12)
month_names = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
revenue = [16000, 14000, 17500, 19500, 21500, 21500, 22000, 23000, 20000, 19500, 18000, 16500]


fig, ax = plt.subplots(figsize=(12, 8))
ax.set_xticks(months)
ax.set_xticklabels(month_names)

#Set the margin (10% higher and lower)
y_upper = [i * 1.1 for i in revenue]
y_lower = [i * 0.9 for i in revenue]

#this is the shaded error
plt.fill_between(months, y_lower, y_upper, alpha=0.2) 
plt.plot(months, revenue)
plt.show()

# %% [markdown]
# # Pie Chart

# %% [markdown]
# If we want to display elements of a data set as proportions of a whole

# %% [markdown]
# Pie charts are helpful for displaying data like:
#
# - Different ethnicities that make up a school district
# - Different macronutrients (carbohydrates, fat, protein) that make up a meal
# - Different responses to an online poll

# %%
payment_method_names = ["Card Swipe", "Cash", "Apple Pay", "Other"]
payment_method_freqs = [270, 77, 32, 11]

plt.figure(figsize=(12, 8))
plt.pie(payment_method_freqs, labels=payment_method_names, autopct='%0.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Histogram

# %% [markdown]
# Basic metrics of mean, median, or standard deviation.
#
# A histogram tells us how many values in a dataset fall between different sets of numbers
# (i.e., how many numbers fall between 0 and 10? Between 10 and 20?

# %% [markdown]
# All bins in a histogram are always the same size. The width of each bin is the distance between the minimum and maximum values of each bin, Each bin is represented by a different rectangle whose height is the number of elements from the dataset that fall within that bin.

# %% [markdown]
# example.
# If we want more than 10 bins, values from 66 to 69, divided into 40 bins (instead of 10
#
# - plt.hist(dataset, range=(66,69), bins=40)

# %% [markdown]
# ### `Multiple Histograms`

# %% [markdown]
# Compare two different distributions

# %% [markdown]
# code:
#
# plt.hist(a, range=(55, 75), bins=20, alpha=0.5)

# %% [markdown]
# ### `Problem we face is that our histograms might have different numbers of samples, making one much bigger than the other.`

# %% [markdown]
# To solve this, we can normalize our histograms using normed=True /
# ### Note: higher version use density=True

# %% [markdown]
# a = normal(loc=64, scale=2, size=10000)
#
# b = normal(loc=70, scale=2, size=100000)
#
# code:
#
# - plt.hist(a, range=(55, 75), bins=20, alpha=0.5, normed=True)
# - plt.hist(b, range=(55, 75), bins=20, alpha=0.5, normed=True)

# %% [markdown]
# # Review:
#
# `Line graph` = display quantitative variables ex. temperature oer time, sales per months
#
# `Bar graph`  = diffirences between categorical variables
#
# `pie graph`  = proportion of a whole data
#
# `Historam`   = display distribution of a dataset

# %% [markdown]
# # Exercises

# %% [markdown]
# # Test average per year with margin of error

# %%
past_years_averages = [82, 84, 83, 86, 74, 84, 90]
years = [2000, 2001, 2002, 2003, 2004, 2005, 2006]
error = [1.5, 2.1, 1.2, 3.2, 2.3, 1.7, 2.4]

# Make your chart here
plt.figure(figsize=(10,8))
plt.bar(range(len(past_years_averages)), past_years_averages, yerr = error, capsize=5)
plt.axis([-0.5, 6.5, 70, 95])

ax = plt.subplot()
ax.set_xticks(range(len(years)))
ax.set_xticklabels(years)

plt.title('Final Exam Averages')
plt.ylabel('Test average')
plt.xlabel('Year')

# plt.savefig('my_bar_chart.png')
# plt.show()
# Out:
# <ipython-input-15-8ffa3b8bf848>:10: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot()
# Text(0.5, 0, 'Year')

# %% [markdown]
# # This displays the differences in average test scores between students who went to two different middle schools before enrolling in your high school.

# %%
unit_topics = ['Limits', 'Derivatives', 'Integrals', 'Diff Eq', 'Applications']
middle_school_a = [80, 85, 84, 83, 86]
middle_school_b = [73, 78, 77, 82, 86]

def create_x(t, w, n, d):
    return [t*x + w*n for x in range(d)]
school_a_x = create_x(2, 0.8, 1, 5)
school_b_x = create_x(2, 0.8, 2, 5)
# Make your chart here
plt.figure(figsize=(10,8))
ax = plt.subplot()  
plt.bar(school_a_x, middle_school_a)
plt.bar(school_b_x,middle_school_b)
middle_x = [ (a + b) / 2.0 for a, b in zip(school_a_x, school_b_x)]

ax.set_xticks(middle_x)
ax.set_xticklabels(unit_topics)

plt.legend(["Middle School A", "Middle School B"])
plt.title('Test Averages on Different Units')
plt.ylabel('test average')
plt.xlabel('unit')
plt.show()

# %% [markdown]
# # This graph displays the breakdown of students who got As, Bs, Cs, Ds, and Fs in each unit.

# %%
unit_topics = ['Limits', 'Derivatives', 'Integrals', 'Diff Eq', 'Applications']
As = [6, 3, 4, 3, 5]
Bs = [8, 12, 8, 9, 10]
Cs = [13, 12, 15, 13, 14]
Ds = [2, 3, 3, 2, 1]
Fs = [1, 0, 0, 3, 0]

x = range(5)

c_bottom = np.add(As, Bs)
d_bottom = np.add(c_bottom, Cs)
f_bottom = np.add(d_bottom, Ds)
#create d_bottom and f_bottom here

#create your plot here
plt.figure(figsize=(10,8))
plt.bar(x, As)
plt.bar(x, Bs, bottom=As)
plt.bar(x, Cs, bottom=c_bottom)
plt.bar(x, Ds, bottom=d_bottom)
plt.bar(x, Fs, bottom=f_bottom)

ax = plt.subplot()
ax.set_xticks(range(len(unit_topics)))
ax.set_xticklabels(unit_topics)

plt.title('Grade distribution')
plt.xlabel('Unit')
plt.ylabel('Number of Students')
# Out:
# <ipython-input-17-80bfd6992723>:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot()
# Text(0, 0.5, 'Number of Students')

# %% [markdown]
# # This displays the breakdown of final exam scores between your first year of teaching vs your second year of teaching.

# %%
exam_scores1 = [62.58, 67.63, 81.37, 52.53, 62.98, 72.15, 59.05, 73.85, 97.24, 76.81, 89.34, 74.44, 68.52, 85.13, 90.75, 70.29, 75.62, 85.38, 77.82, 98.31, 79.08, 61.72, 71.33, 80.77, 80.31, 78.16, 61.15, 64.99, 72.67, 78.94]

exam_scores2 = [72.38, 71.28, 79.24, 83.86, 84.42, 79.38, 75.51, 76.63, 81.48,78.81,79.23,74.38,79.27,81.07,75.42,90.35,82.93,86.74,81.33,95.1,86.57,83.66,85.58,81.87,92.14,72.15,91.64,74.21,89.04,76.54,81.9,96.5,80.05,74.77,72.26,73.23,92.6,66.22,70.09,77.2]

# Make your plot here
plt.figure(figsize=(10, 8))
plt.hist(exam_scores1, bins=12, density=True, histtype='step', linewidth=2)
plt.hist(exam_scores2, bins=12, density=True, histtype='step', linewidth=2)

plt.legend(["1st Yr Teaching", "2nd Yr Teaching"])

plt.title("Final Exam Score Distribution")
plt.xlabel("Percentage")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # This displays what students think the hardest topic covered throughout your math course is.

# %%
unit_topics = ['Limits', 'Derivatives', 'Integrals', 'Diff Eq', 'Applications']
num_hardest_reported = [1, 3, 10, 15, 1]

#Make your plot here
plt.figure(figsize=(10,8))
plt.pie(num_hardest_reported, labels=unit_topics, autopct="%1d%%")

plt.axis('equal')
plt.title('Hardest Topics')
# Out:
# Text(0.5, 1.0, 'Hardest Topics')

# %% [markdown]
# # This displays the relationship between the time students say they studied and the scores they received on their final exams.

# %%
hours_reported =[3, 2.5, 2.75, 2.5, 2.75, 3.0, 3.5, 3.25, 3.25,  3.5, 3.5, 3.75, 3.75,4, 4.0, 3.75,  4.0, 4.25, 4.25, 4.5, 4.5, 5.0, 5.25, 5, 5.25, 5.5, 5.5, 5.75, 5.25, 4.75]
exam_scores = [52.53, 59.05, 61.15, 61.72, 62.58, 62.98, 64.99, 67.63, 68.52, 70.29, 71.33, 72.15, 72.67, 73.85, 74.44, 75.62, 76.81, 77.82, 78.16, 78.94, 79.08, 80.31, 80.77, 81.37, 85.13, 85.38, 89.34, 90.75, 97.24, 98.31]

# Create your figure here
plt.figure(figsize=(10,8))

# Create your hours_lower_bound and hours_upper_bound lists here 
# list comprehension
hours_lower_bound = [element - (element * 0.2) for element in hours_reported]
hours_upper_bound = [element + (element * 0.2) for element in hours_reported]

# Make your graph here
plt.plot(exam_scores, hours_reported, linewidth=2)

plt.fill_between(exam_scores, hours_lower_bound, hours_upper_bound, alpha = 0.2)

plt.xlabel("Score")
plt.title("Time spent studying vs final exam scores")
plt.ylabel('Hours studying (self-reported)')
# Out:
# Text(0, 0.5, 'Hours studying (self-reported)')
